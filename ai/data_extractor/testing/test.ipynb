# %%
from pathlib import Path

cwd = Path.cwd()

QnA = r"C:\All University Materials\Project\ICT304-project\ai\data_extractor\data\raw"

# %%
import re

def search_txt_files(dir_path : str, files=None):
    
    if files is None:
        files = list()
    
    current_dir = Path(dir_path)
    
    for item in current_dir.iterdir():
        
        if re.search(r'\.txt', item.name):
            files.append(item)
        elif item.is_dir():
            search_txt_files(str(item), files)
            
    return files

# %%
import re

def create_qna_pairs(split_txt_list : list):
        
    pair_storage = []
    
    i = 0
    while i < len(split_txt_list) - 3:
        
        Q = split_txt_list[i].strip()
        A = split_txt_list[i + 2].strip()
            
        is_Q = re.search(r"^([Qq].?)$", Q) is not None
        is_A = re.search(r"^([Aa].?)$", A) is not None
        
        print(is_Q and is_A)
        
        if is_Q and is_A:
            
            question = split_txt_list[i + 1].strip()
            answer = split_txt_list[i + 3].strip()
            
            pair_storage.append({'Question': question, 'Answer': answer})
            
            i += 4
        else:
            i += 2
            
        
            
            
    
    """while len(split_txt_list) >= 4:
        
        pair = split_txt_list[:4:]
        
        A = pair[1].strip()
        Q = pair[3].strip()
        
        if len(A) > 5 and len(Q) > 5:
            pair_storage.append({'Question' : A, 'Answer' : Q})
        
        split_txt_list = split_txt_list[4::]"""
        
    return pair_storage

# %%
[1,2,3,4][:3]
# Out:
# [1, 2, 3]

# %%
def extract_qna_pairs(txt_file_paths: list[Path]):
    
    text = []
    
    for txt_file in txt_file_paths:
        with open(txt_file, 'r', encoding='utf-8', errors='ignore') as f:
            raw_text = f.read()

            # split on Q and A tags
            split_text = re.split(r'(\n+[AaQq].?\n)', raw_text)
            
            # remove the preamble from shri's top text
            while split_text and re.search(r'^([AaQq].?)$', split_text[0].strip()) is None:
                split_text.pop(0) 
                
            text = text + create_qna_pairs(split_text)
                
    return text

# %%
pairs = extract_qna_pairs(search_txt_files(QnA))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# False
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
pairs
# Out:
# [{'Question': "The example in the slides show it being used for a class, should we be making separate data dictionaries for every class? or should we just have one data dictionary that has all the classes in it?\n  \nShould we write them for Structs too? What about functions that aren't part of a class?",
#   'Answer': 'You can have as separate tables for class or one long table. My preference is separate but not fussed.\n\nYes, include for structs as rationale is needed for having these too. Structs are also encapsulation.\n\nClasses and structs create type, and so documentation is needed in the dictionary.\n\nMore related questions below.\n\n\n\nNormal subroutines, no, not part of table. These are done differently but not part of this unit. Done in other units.'},
#  {'Question': 'Just a question about Try/Catch in C++ and the Assignment.\nSince we are not allowed to use STD:: types, how will we catch errors being thrown?\nBecause we were not told how to write error classes and the Assignment says to not use any std classes besides string, cout, cin, stringstream and fstream.',
#   'Answer': 'For exceptions, you can use the approach shown in Topic 7 where the Stack code is provided. Or assert. Or you can use the ones for the built in types as shown in the textbook.\n\nThe textbook has good explanations of exception handling in its own chapter where exceptions can be thrown using the built in types like int and string.'},
#  {'Question': 'But since DataRecType is a struct, should we make getters and setters and make it more like a C++ class?\nBecause it violates SOLID.',
#   'Answer': "Having setters/getters for struct wouldn't make sense as everything is public. Making it a class, would require reason for why you need to encapsulate. Keeping it as struct would also require a reason. So the rationale for encapsulation type would be defended. Review workshop recording.\n\nSOLID has many principles behind one acronym. Better to indicate the specific principle(s) being violated and why, when writing your rationale."},
#  {'Question': 'another quick question - when doing my solar radiation calculation i am landing with numbers under 1 - around 0.1 mostly, is this correct? why does the assignment sheet show results output in the hundreds?',
#   'Answer': 'Those are made up examples to show output format. You can see that it is a made up year 1905. IoT sensors connected to computing systems didn\'t exist then.\n\nThe assignment specs also indicate that it is "made up".\n   \nNot all monthly values would be below 1. Depends on the data file, month and year.\n\nBTW, what would the conditions be like if SR wasn\'t made up, but was for real 200 kWh per sq m?'},
#  {'Question': "I heard the we have to use solid in the assignment. Do I loose marks if I didn't use? My assignment is working.",
#   'Answer': "If you violate the SOLID principles or MVC, no marks will be given for the assignment. It does not matter if the assignment is working and gives the correct output. \n\nViolating these principles if you are a developer or software engineer in a company has massive financial consequences for the company because maintenance cost goes up, and the software is not robust. So in an assignment, you should be getting negative marks. But we don't give negative marks, so the best that can be given is no marks.\n\nAll of the essential requirements were covered in the workshops/clinics over the past few weeks. Please go through all recordings very carefully. The PowerPoint slides and lab 5 QandA provide further information on what is expected.\n\nSo please don't violate SOLID or MVC.\n\nConsider reviewing the SOLID principles in this tutorial. It is short and it shows violation of the principles and how to correct the violation using simple Java like examples. https://www.freecodecamp.org/news/solid-principles-for-better-software-design/\n\nThe very first example in the above tutorial reinforces what we were doing in the lab 4 assessment. I/O had to be moved out of the data classes (single responsibility as well as separation of Model from View). So please examine the examples carefully."},
#  {'Question': "Hello, as I understand for assignment 1 we must export / display all numbers to the first decimal place, and i'm attempting to do this with setprecision from <iomanip>, however when I add it I get an error that I found was caused because apparently calling #include <iomanip> calls #include <time.h>, which creates an error as we have our own time.h I was wondering if we are allowed to rename Time.h to avoid this issue.",
#   'Answer': 'Yes you can change the name of your Time.h. You decide what you want to call it.'},
#  {'Question': 'I understand the reason for Vector(unsigned i) being a problem. What if in my Vector the user is not allowed to change.\n\nunsigned size;\n\nWould that be ok.',
#   'Answer': "Yes that can be acceptable and makes sense if you are after large Vector provided the user of Vector can't change it directly (private and no setter). The can see it via a getter, but shouldn't be able to change directly.\n\nI am assuming that maxsize is also unsigned and there is no write access by user of Vector.\n\nBut you need to consider what happens when the application programmer does the following:\nVector<int> v(-1); // or any negative number. Try and see what happens."},
#  {'Question': 'What is the problem with this constructor using unsigned. You indicated it is not good.\nVector(unsigned i);',
#   'Answer': "That is for your template Vector, but the problem is rife in codebases.\n\nModify the constructor to print out the parameter i, capacity and size that gets set.\n\nThen, write a test for your Vector that tests the following:\n\nVector<int> vec(10);\n\nIf the above tests ok, test the following:\n\nVector<int> v(-1);\n\nNote that when the Vector has a non-default constructor as asked for lab 5:\nVector(int n);\n\nThis constructor also does implicit type conversion. It can covert an int into a Vector. The keyword explicit would need to be used if you don't want implicit type conversion.\nSimple explanation:\n   https://www.ibm.com/docs/en/zos/3.1.0?topic=only-explicit-conversion-constructors-c\n\nLonger explanation:\n   https://en.cppreference.com/w/cpp/language/explicit"},
#  {'Question': "I am passing Windlog struct to my std_dev and mean routine. I heard that is not correct. Can I double check with you that I don't loose marks.",
#   'Answer': "It is wrong and you will get a low mark to reflect this incorrect approach, as this approach shows that you are unable to abstract the essence of these general statistical routines. The statistical routines that you are using in the Assignment should also be usable in lab 4 question 7.\n\nBy coupling an application data type to general statistical routines, the routines have become useless outside the current application. For example, you will need to write new routines to deal with financial data. So design for reuse in other applications.\n\nYou can couple the stats routines to your Vector, as the Vector is just a carefully controlled array. What other Vector constructor would you need, so that application programs don't have to worry about having to use your Vector, and just work with whatever arrays they have been working with?"},
#  {'Question': "For my date and time classes I have kept the input and output operators in date.h and time.h. You had told me to remove them as putting the operators in the .h files violated MVC. I think I understood what you told me, but now I think I am not so clear as I didn't write it down.",
#   'Answer': 'I/O is tied to formatting. That is what the input data or output data looks like. It is part of the "View". The model is the actual data class, Date and Time for this work. You need to uncouple the View from the Model. Remember what you would have done in first year about "Coupling" (and also Cohesion). \n\nIf the Model is coupled to the View, if the View needs to be changed, the Model has to be changed resulting in large code changes throughout the code base. The assignment in this unit is tiny compared to code bases out there, but the principles still apply and you must always follow the principle where you minimise coupling. All this was discussed in the workshops. \n\nIf you keep the View with the model, you will get no marks. Not getting marks is really a small price to pay compared to what would happen with industry code where a small change in the View in a poorly designed code base results in changes proliferating throughout the entire code base (Jelly effect referred to in the PowerPoint slide and workshops), leading to bugs, cost overruns, delay in delivery.\n\nLab 4 was about removing the View, including the formatting concerns from the Model, and the lessons must be utilised and built upon moving forwards.\n\nMinimising coupling and increasing cohesion rules must never be violated. You would know this from ict159 last year where a mark of 0 would be given for the entire assignment if modularity rules were not followed. This is coming from industry as we become more industry focussed. \n\nSo do not violate SOLID. The cost is heavy and it does not matter if the code works now. The problem will occur later.'},
#  {'Question': 'For my Assignment 1 design I have encapsulated a time and date class into a struct for use with my Vector. I have added the wind data as loose members in the struct, though I’m not sure this is a good approach.\n\nI was wondering if it would be better to have the air data in its own class, or have the air data as members within the struct?',
#   'Answer': "These are the decisions that would need to make and justify. These things are assessed so I actually can't give the answer.\n\nYou might want to consider why class is used for the air data. Is there any behaviour that you want to control/manage in air data? If there is, then you need class. There was more discussion about this in the workshop."},
#  {'Question': 'Can I use memcpy?',
#   'Answer': 'No, these algorithms/routines are not allowed for assignment 1. Similar question in lab 5 QandA for realloc.'},
#  {'Question': 'Just for confirmation so I don\'t need to provide a specific "test program" for the main program right? just the classes. So the testing of the main program would consist of console output from tests using different test files to check the test plan.',
#   'Answer': 'The console output similar to the ict159 revision exercise is expected. The requirements of the ict159 submission was set some years ago using the ict283 requirements, so that is one of the reasons the revision is done. So the test plan would have corresponding console output and labelled to match.'},
#  {'Question': 'is it ok to use stringstream (#include <sstream> ) in our main program of assignment 1?',
#   'Answer': 'Yes you can use the basic types like int, float, char, etc., as well as string and stringstream.'},
#  {'Question': "For this particular solution I no longer use variable length arrays, and just expose the internal array for my vector class via a public function (returning a T const *).\nI get the feeling that this isn't entirely reliable but it avoids data duplication.",
#   'Answer': 'No it is worse than that. If later on, you change the implementation to some other data structure which does not use contiguous storage in memory, every client program that uses your data structure will break.\n\nThe designer of a data structure should never allow a coupling between a client program and the internals of a data structure. All the client program knows is the interface for the data structure. See the PIMPL idiom in the coding standards book that was pointed out in one of the workshops. Although the advise is to use this idiom judiciously, the reasons that argue its usage should be taken to heart even if the PIMPL idiom is not used.\n\nYou should be careful that a getter should not allow modification of the data. A getter is meant to just return data, not modify it. See rule 15 Use const proactively in\n"C++ coding standards: 101 rules, guidelines, and best practices". The getter should also prevent itself from modifying class data by having const on the right hand side.\n int GetCredits() const;\nIt is the setters job to modify data, not the getters, so don\'t mix behaviour as you can loose all the code marks for providing unsafe code. This idea applies to any code you write not just C++ code.'},
#  {'Question': "In regards to assignment 1, are we allowed to use regex (#include \n<regex>) for input validation?\n\nI figure it would be cleaner than having to do lots of stuff with \ngetline's, but was unsure if we are allowed to.",
#   'Answer': 'Not for assignment 1 or any work prior to assignment 1. You have to do it all using your own code to get first-hand appreciation of the issues, including the processing that is involved.\n\nYou can use it after assignment 1 as would have an appreciation of the issues then. If you use any of these now, you will get nothing for the code.'},
#  {'Question': 'Question related to how to print the output kWh per sq m for option 3.',
#   'Answer': 'Use either kWh/m^2 or kWh/m2.\n\nThe preferred version is kWh/m^2 as that is more clear but will accept either one.'},
#  {'Question': 'I was curious in assignment 1 am I able to use enums?',
#   'Answer': "Yes, of course you are. It is part of the language and is part of the topic readings. Only the stuff that has been explicitly excluded are the ones you can't use. \n\nRelated question about can't be used is also below."},
#  {'Question': "I have a quick question to ask regarding the assignment 1 documentation for ICT283. I've created a 'menu.h/.cpp' in order to move all the functions that I had cluttering in main moved to the 'menu.h/.cpp'. Now I'm wondering if I need to have 'menu' in my UML, or in the algorithm, and data dictionary when it's not really a class, it just helps execute its own functions in main to do the menu options that we need. Keep in mind that 'menu' is another set of '.h/.cpp' files but it isn't necessarily a 'class' with private member variables of the class and so on so I'm a bit stuck on what to do.",
#   'Answer': 'You have it in UML only if you have a menu class, like\n\nclass Menu {...\n\n};\n\nIf it is just a subroutine, then it is not in UML class diagram (it is not a class). It is an algorithm.\n\nThe .h/.cpp is not the deciding thing if it is going to be in a class diagram or not. To be in the class diagram, it must be a class.\n\nThe .h/.cpp is for separating the interface from the implementation. This occurs in C programs too. There was more discussion of this in the workshops/clinics'},
#  {'Question': "I had a quick question I asked to ask. Would inheritance be allowed for Assignment 1? I've gone through quite a few different design ideas, listing down each pros and cons, but struggling to identify one that I think would be good. I've noticed that a few possible designs seems more efficient to implement inheritance. Just wanted to check that I would not be marked down for using inheritance (mainly since we haven't covered it in labs) and that it would be fine if I did as it has been something we've covered in the workshops and lecture notes. I feel like we are as I don't see a reason why we're not allowed since it's apart of OOP but I just wanted to be certain.",
#   'Answer': "What is not allowed is made explicit in the assignment.\n\nThere is no prohibition on inheritance.  It has been covered in some detail in the notes and in the workshops.\n\nJustify carefully. Make sure you don't violate the L in SOLID."},
#  {'Question': 'Would my program read in both files or just one?',
#   'Answer': 'Just read in one file and then show the menu. \n\nThe program should be able to work in case the other file is chosen, or another test file that you have not seen with a different arrangement of columns. See more on testing below.'},
#  {'Question': "For our external documentation, is there a template like in previous units that we must follow or are we free to do our external documentation however we like. (as long as it's appropriate of course)",
#   'Answer': 'You can use the one from the revision exercise. Update it where you have the structure chart, you have UML and Data Dictionary table. More Question and Answer related to this below.'},
#  {'Question': 'One line on page 6 specifies that:\n"STL data structures/algorithms cannot be used in this assignment".\nI understand what STL data structures are but I\'ve never heard of STL algorithms before, as long as I don\'t include <algorithms> will I be fine? Cause I know data structures can refer to more than just vectors, like stack, queues, etc. And I don\'t want to include something related to STL algorithms.',
#   'Answer': 'That is right. Do not #include <algorithm>\nAnd you are right about not including STL data structures. They are in the std namespace.'},
#  {'Question': "I had discussion with my (external) tutor regarding Lab 5 Exercise 5, about if I had a function that read in like 10 columns at once, would it be poor cohesion? Which he replied by saying it would not be as that function's only responsibility is getting specific data from a file. Would you say this is true despite the fact that the function is getting data from multiple specific columns as that seems like more responsibilities, straying it away from high cohesion?",
#   'Answer': "Your tutor is correct. The input routine's job is to load the contents of the file into data structures."},
#  {'Question': 'I had a question regarding design, but in a more general sense, specifically what are some indicators when a class becomes too bloated with members that are yet relevant to the class. I find it difficult to determine when a class gets to a point where there are too many responsibilities in it.',
#   'Answer': 'Ask if a particular method is nice to have as it makes it convenient for users. Removing that method would make it inconvenient to users. If the answer is "yes", remove the method and make it a helper routine separate from the class.\n\nOther indicators are that some of the algorithms (thus code) has some similarities. \n\nThe only time you don\'t remove a method is when the class can\'t do its job without that method. \n\nThe remaining methods can be called in different combinations to get the behaviour needed. It is inconvenient as it can require the client programmer to make this combination, but a decent client programmer would know how to package the calls in subroutines to get what they want.'},
#  {'Question': "Just had a question about the data files we'll be reading into the program. In the assignment sheet, it says that if I downloaded my own data, I should remove the first few rows if the sensor list is there.\nIn the data files we have, the first row in both files has the sensor list. For our assignment, should I be removing that first line in Notepad++? Or will those be read in for our assignment and I should account for the first row not containing any data?",
#   'Answer': "No, don't delete the first row in the data files provided. It has to work the same way as q5 of lab 5 to indicate which columns have what data.\n\nDownload your own data files and see the difference."},
#  {'Question': 'I remember you saying that the algorithms for assignment 1 should not be programming language specific.\n\nDoes this mean I should not include algorithms that deal with pointers. Such as the algorithm to copy over dynamic arrays and increase the size of a dynamic arrays?\n\nSince quite a few programming languages don’t have pointers.',
#   'Answer': 'If algorithms had pointer syntax, Java programmers would be confused. That is why I advised looking at our reference book Intro to Algorithms. You will see that the . notation as in Java is used. C++ and Java programmers know what that means and C++ programmers would know how to covert that concept into pointers.\n\nPointer syntax are language implementation specific.'},
#  {'Question': 'For the algorithms submission in assignment 1, do I include algorithms for functions that aren’t in the UML? (for example, the functions that calculate mean and std deviation).',
#   'Answer': "Any subroutine/method that is non trivial would have an algorithm. Remember the revision exercise that you had to, it is the same. *Don't* provide algorithm for trivial setters/getters. That would just be clutter."},
#  {'Question': 'When outputting the standard deviation, do we use the standard deviation of the data from the CSV before conversion to the correct output format or after?\n\nFor example, in the month of March, 2014 the mean is 5.6m/s or 20.3km/h and the standard deviation on the data in m/s is 3.0 and the standard deviation on the data in km/h is 10.9.',
#   'Answer': 'It is a good question and the answer for this was decided by the statisticians who came up the idea of stddev, possibly a few hundred years ago. It has to do with the data that is being reported on. The stddev is a "measure" of the variance in the data. It is the sq root of the variance.\n\nSo if you are reporting the mean of the data, you must report the stddef. So you use the same units that the mean is reported in. The stddef shows how representative the mean is. So if you don\'t report the unit like m/s or km/h it is assumed that the unit is the same as the unit for the mean. \n\nBest to read the wiki link given to see the meaning of what the program is meant to be reporting.'},
#  {'Question': 'How do you want us to represent a struct in starUML? Is it treated like a normal class or is there specific syntax also do we need to provide algorithms for the client program or just the classes?',
#   'Answer': 'At one of the earlier classes, we looked at differences between struct and class. They are both similar except for default behaviour. To distinguish you write <<struct>> stereotype together with the class name in UML, and everything is public. I think someone may have asked this too during one workshops/clinics.\n\nAlgorithms are needed wherever there is non trivial processing. Same way as in the revision exercise at the start of semester. This means all non-trivial routines. Do not write for trivial pass-through setters/getters.'},
#  {'Question': "In my data dictionary I've got an extra column for rationale and for every method other than a setter/getter I've mentioned why I've chosen to implement those methods and so on. Do I need to write a paragraph or two about the overall design and why I've designed each class to work the way it does on top of what I've done already in the data dictionary such as the column for rationale?",
#   'Answer': "Yes, include a paragraph about your overall approach is a good idea. Don't go into details about what each class has, but how the classes work with each other. \n\nPutting in the extra thinking process is what distinguishes a good assignment from an average assignment."},
#  {'Question': "With adding the temp(T) and solar radiation(SR) are we expected to put them in the same struct as windlog or create individual struct for each. I'm thinking of creating separate structs for each despite the duplication of date & time data because you may only want to delete a temp reading without losing anything else, Is this a reasonable approach?",
#   'Answer': 'The approach you use is entirely up to you. You will need to justify why you took any particular approach.\n\nYou are not being directed to do it one way or another as you have to come up with your own design and defend (justify) that design. Use the theory (principles) to defend your approach.'},
#  {'Question': 'I have another question regarding the universal sum method shown in the class.\n\ntemplate<class T>\nT sum(const vector<T> &array){\n}\n\nI understand how it works and everything but i am struggling with how to implement it in the assignment as i pass the windLog struct in and then select the speed variable inside my sum method.',
#   'Answer': "Lets say you did come up with a solution that enables the sum function to do the selection of what to sum inside the templated sum, and then do the sum. \n\nHow would you then defend that approach using the Single responsibility (cohesion), or any of the other principles? What happens when you need to sum the temperature? Would a change in the routine be needed? Although relative humidity is not used in this assignment, if the requirements were to change to include relative humidity, how would this template sum routine be used?\n\nConsider how many separate tasks a sum routine that not only does summing but does more (selecting what to sum) would have to do and how sum would conform to the single responsibility principle. Do not think long and hard about this. It is an old and established principle. Just apply the principle.\n\nBTW, sum as shown above, is not a method. It does not belong to a class. \n\n\nQ - supplementary to the above\nThe only way i can think of to implement the universal method is by extracting the speed variable from windLog and storing them in a temporary vector that is then passed into sum. Is this an appropriate solution, or is their a better one? \n\nA  supplementary to the above:\nThe answer to this question will depend very much on the answer to the previous one. Which principle (or principles) can you use to defend your approach. \n\nThe solution that you go for is the one that you can defend using theory. \n\nIf the approach can't be defended using theory, then the approach would be wrong even if the right answer is generated.\n\nNote that I am not answering your question about which is the better one as you need to answer it in the assignment."},
#  {'Question': "Are we allowed to create new classes for our implementation?  I am assuming we are but I don't want to start making them before some confirmation.",
#   'Answer': 'Yes, you have freedom to create as many classes you like. You will have to justify each one, as the thinking behind your design choices is needed.'},
#  {'Question': 'Just confirming that I can use the test plan table from lec 12 powerpoint and testing is just the screen dumps of test runs like the previous units.\n\nFor the evaluation.txt, there are only two parts in point form?',
#   'Answer': 'Yes, the intention is to use the test table from Lec 12 as indicated in one of the earlier workshops. You may choose the test table from the revision exercise (ict159) document that you filled in at the start of semester.\n\nTesting is screen dumps. Label the screen dumps with the test numbers from the test plan. \n\nCopy/paste the dumps and create a pdf file. You may have done screen capture in previous units, but you don\'t need to screen capture. You can just copy/paste the text from the console and that would count as fulfilling the requirements "Output of test run(s)". Keep it tidy. For some students screen capture is convenient, so screen capture.\n\nEvaluation.txt has two headings "What works" and What doesn\'t work" and done in dot points as indicated in the assignment specs.\n\nYou can, if you like, add ideas for improvement in the evaluation.txt. Particularly if you found after completing the assignment that you could do certain things differently.'},
#  {'Question': 'I have got question 5 working with normal array. Still trying to get Vector to work but data is missing after I resize and it is really weird. The thing is can I submit the working question using normal array for this question.',
#   'Answer': 'You can, but keep in mind that the Vector is assessed in the assignment.\n\nThe issue of the missing data after resize is discussed in lab 5 QandA.'},
#  {'Question': 'I have decided to use setAt and getAt for the Vector instead of []. Would this be ok?\n\nAre [] more powerful than normal methods like getAt or setAt?',
#   'Answer': 'Examine the specifications of Vector carefully. It is just an encapsulated raw array and thus Vector should behave like a normal array but with certain protections. To behave like a normal array, the interface must be that of an array. If you change the interface then you have changed how the user interacts with it.\n\nSo think very carefully, and provide your reasons in the data dictionary table (Lec 11. ppt of Topic 4).\n\nI am not sure of the context of "powerful" that you are referring to.\nop[] has the intuitive usage in the array context. It takes an index\nand returns an element. A bit more on this in the lab5 QandA. It is\nno different to a subroutine call. \n\nAs an overloaded operator, you shouldn\'t change the semantics (meaning) of the operator. What does rule 26 say about operators? See the unit reference book C++ Coding Standards ebook from the topic readings.\n\nA normal routine can have a number of parameters and can return data back like functions. So [] can\'t do everything compared to a normal routine like setAt or getAt, but [] is more intuitive usage for arrays or data stored in consecutive memory locations and indexing makes sense.\n\nThe Vector you have to use is an encapsulated array, so you will need to justify why your removed conventional array behaviour and violated Vector requirements.\n\nSo the choice is really up to you and how you justify your choice. Your justification may not be accepted if you not put careful thought into the decision.'},
#  {'Question': 'In assignment 1, should i be appending to the data file or \noverwriting it for menu option 4?',
#   'Answer': "Wasn't specified, so either approach is fine."},
#  {'Question': 'Are we meant to only display the output to 1 decimal place? E.g. 29.2',
#   'Answer': 'Yes, that is the intention.\n\nSo when a client shows an output format, the format needs to be \nfollowed.'},
#  {'Question': "QN1: Am I supposed to download the data for each year from 1998 to \n2016 and put them in one file?\n\nQN2: (If yes to QN1) Should I prevent the user from inputting year \nvalues that aren't between 1998 and 2016 (inclusive)?",
#   'Answer': 'No just the files provided. \n\nNever put restriction on the date. Your program will not work if we use a different date range for testing. Then it will count as a non-working program.'},
#  {'Question': 'I\'m finishing up my program and I wanted to ask you something related to client-side design. It\'s really about keep the main.cpp a bit more tidy. \n\nAt the moment I have several functions in main.cpp, some are operator overloads, others are for the menu. I like to keep these functions in my main.cpp and not create classes for them as they will likely need to be changed in the future. However, the main.cpp is getting a bit busy.\n\nI was just wondering, would it be considered good practice to move, for example, all the menu functions ini a "Menu.h", without making a class out of it? The functions would still be globals as they are now, but they would not be in my main.cpp.  More importantly, if I decide to go that way, is there any particular way I should document this?\n\nI could keep my functions in my main.cpp, but I\'d prefer to clean it up a bit, so I was curious about whether that is a good approach.\n\nPlease, let me know if you think that is an acceptable solution',
#   'Answer': "It is a better solution to keep main tidy. So menu.h with menu.cpp would be a good way to go. You don't have to create a class if your design doesn't warrant it, but where ever possible separate specification (.h) from implementation (.cpp or .c). The only time you don't do this .h and .cpp seperation is for template classes like Vector. That is why the Vector class only exists as Vector.h."},
#  {'Question': "I'm curious as to what the preferred method for exception handling \nwill be in assignment 1 (eg class setter methods handling \nout-of-bounds parameters etc.).\n\nShould we use the inbuilt method of try-catch blocks and throwing \nexceptions, or use method return values to indicate invalid parameters?",
#   'Answer': 'You can use boolean return, try/catch blocks or assert the \nprecondition. Use the one most suitable and explain your decision.\n\nYou should first use normal error messages and it is only when normal error messages are not suitable, use exception handling approaches. Note that the error message approach relies on there being a console. For data structure classes it would not be a good assumption to make as there may not be a console but a GUI application that is using the data structure. But for the assignment it is acceptable for now.\n\nSimilar question in Lab 5 QandA.'},
#  {'Question': 'The menu options shows example output. Do I have to follow this\nor can I choose my own output style?',
#   'Answer': "You *must* follow. If you don't, your program would be considered\nas not working properly. It would also fail objective 6 of the \nassignment."},
#  {'Question': 'Can I create a Weather class to store the solar, wind and temp data? Or can I only use the Date, Time and Vector classes?',
#   'Answer': 'You decide how you do it and provide your reasons (rationale). The \nquality of your decision is being assessed in this assignment as well \nas in later work.\n\nTo help you decide, think of what "cohesion" means.\n\nAlso be careful to NOT introduce unnecessary coupling.'},
#  {'Question': 'In the event that our design changes after we have already done \ntesting on that method should we keep the old tests in addition to \nthe new tests?  Maybe noting the old ones as being from old versions \nor something.',
#   'Answer': "If the old tests are not relevant to what you have got now, don't include the old tests in the tests folder as the old code is not there any more.\n\nAny test that is provided needs to be relevant for the current version."},
#  {'Question': 'I am using Vector class that comes from the textbook. It is not the STL vector but an actual class where all the code is provided. In the textbook it is not called a Vector class but I can see that it looks like one, so I have changed the name to Vector. It provides a lot of methods including print. I was told that Data Structure classes must not do input or output. Is it ok to have print as a method?',
#   'Answer': 'Your information is correct - data structure classes shouldn\'t do I/O. The class that is in the textbook has a lot of methods (bloated). You need to decide which ones are absolutely essential and which ones are good to have. The ones that are *absolutely essential* remain as methods (good cohesion) and the methods that are "good to have" or helpful to the user of the class become helper routines.\n\nHelper routine are non-members and non-friends of a class, similar to what you had to do to the I/O operators for lab 4. You will need to justify your choices in the Rationale part of the documentation needed for the assignment.\n\nIf you are using the class from the textbook, make sure your \nreference it in your documentation and code.\n\nThere is more discussion below for a question related to yours.\n\nThere is a similar question in Lab 5 QandA'},
#  {'Question': 'Would you be testing my program with your own data file.',
#   'Answer': 'Yes, there has never been a time when our own test data file is not used. Not only does this happen for assignments, it also happens when you go for programming competitions. In industry, clients use their own data to perform a series of acceptance tests. The client is not likely to pay unless the acceptance test is passed.\n\nSome of the common situations where your program will break is when\nthere are blank lines at the beginning or end of files. Normally,\nthere isn’t any blank line within the data. Also all data field\nseparators are always present, so that the record format is always\ncorrect, but there could be missing data when a sensor is offline.\n\nIn case you ask for a copy of our test data file, I should let you know that this is never provided. If you accidentally get hold of the data file we use, we need to create a new one.'},
#  {'Question': 'For Assignment 1 should we use names similar to the standard vector \nclass for functions  so that their purpose is clear?',
#   'Answer': "The std vector is from STL. It is bloated where functionality is \nduplicated in some of the methods. Naming conventions are used that \nare borrowed from other data structures like the stack (push, pop).\nThis is totally not helpful from the point of view of abstraction.\nA Vector is not a stack, so must *not* pretend to be one. A Vector \nis a more generic linear data structure.\n\nYour Vector needs to take a minimalist approach. Avoid duplication of \nfunctionality and don't mix names with other more specialised data \nstructures like stacks and queues.\n\nThe Vector for the assignment is **not** the same as the STL vector.\n\nThe entire Specification and Implementation of the Vector for the assignment is about an A4 page of code laid out neatly without the doxygen comments. Also see Lab 5 QandA."},
#  {'Question': 'Of the two files available on the unit site in the data folder, does it matter which we use?',
#   'Answer': 'Use one or the other for assignment 1 at any one time, but your program should work for either. For assignment 2, you may have to use all that is available. There will be more than 2 provided.'},
#  {'Question': '1.  Should we be including the test plan and test output for the unit testing we have done for the date, time and vector classes with the assignment?',
#   'Answer': 'Yes.'},
#  {'Question': 'Do I need to provide algorithms for the setters of date class. I am not doing anything other than setting/getting day, month, year',
#   'Answer': 'No point in providing algorithms for getters and setters that set and return something with no other processing.\n\nIf you are doing validation, then provide the validation algorithm, particularly if you have validation algorithm for leap year.'},
#  {'Question': 'To get the .exe do we copy the project into a new directory, build in release mode, and then move the .exe from bin into that directory? \nWhat other files should be in the directory with it?',
#   'Answer': "Don't have to copy the whole project. Just build in release mode, go into the release directory and copy the .exe. The data/test file(s) is(are) also needed."},
#  {'Question': "With the test plan I have the output as images but I'm having trouble inserting them into an rtf document can I just put them in a folder and reference their location?",
#   'Answer': 'Test plan is just that. It shows what was being tested and the result of the testing. "Result" means if it passed testing or failed. \n\nOutput images are test output, the actual output of the test. If you are having problems, save the program output file as pdf or html.'},
#  {'Question': 'When you say rationale for the design does that mean you also want a ationale for the overall design/classes and not just a rationale for each classes methods and attributes?',
#   'Answer': 'Overall design rationale would explain why you have particular classes.\nThis part is short.\n\nRationale for each method and attribute is longer. Setters for a class can be grouped together, likewise for getters to save time. You should put this in a column in the data dictionary.\n\nSee ppt for Topic 4, Lec 11. It also shows how to do high and low level UML.'},
#  {'Question': 'In the testTree.cpp there are static global variables. Can I use global variables like that in the assignment?',
#   'Answer': 'If you are referring to variables like unit::c and CollectU::i being global variables, try the following to see if they are actually global variables in the way you think global variables are accessible to any subroutine.  Can you change the values from anywhere? Or print out the values from anywhere?\n\nint main(){\n    unit::c = 20; // can you change these values here?\n    CollectU::i = 200;\n\t\n\tstd::cout << unit::c; // is this access possible?\n\n// ... other code from the main()\n\n}'},
#  {'Question': 'Can I use std::hash to hash my data key to get the hash value.',
#   'Answer': 'Yes, you can use std::hash, or use your own hash function if you did the ict159 assignment that involved hashing.\nYou will need to demonstrate in-person the approach you are taking and why you are taking that approach.\n\nRelated QandA below.'},
#  {'Question': "I have a question regarding the minimum requirement in the assignment 2 document. I have copied and pasted the ones found in the bin/debug folder where it has the executable then included the appropriate data folder containing all the files to be read. It works on my machine but it tells me that it can't find libgcc_s_dw2-1.dll and the executable does not work on a machine I tested that does not have any compilers. Am I missing something that should have been in that folder that should go along the executable or is this a possible issue with the project build settings? I do not recall any of the provided documents on how to resolve this issue or where to even start resolving this issue thus I am asking for advice on how to proceed.",
#   'Answer': 'In the compiler settings, select the static link options, then build in release mode.\n\nWhen something is still missing, locate the .dll and place in the same folder.'},
#  {'Question': "I am getting bad problems when the tree is unbalanced. I think I have a solution where I encapsulate my bst in another class and that class is responsible for inserting by hashing first. The wrapper class manages everything that has to do with Bst. \n\nWould this meet the assignment Bst requrements of using the Bst as the assignment code doesn't see the bst at all?",
#   'Answer': "Assignment 2 specifications require usage of the BST. The specs doesn't say how. \n\nIf you encapsulate your BST in a BST manager class which manages the BST, and the assignment makes use of this BST manager class, the requirements for BST is met.\n\nFrom your question, I am assuming that you are thinking of a manger class for your BST."},
#  {'Question': 'Follow up to my previous question is that I have written my own hash function. Can I use my own hash function?',
#   'Answer': 'Yes. \nReview the requirements of good hash functions in Topic 11.'},
#  {'Question': 'I have been thinking about what you had mentioned in the tut. I like the idea where all the data from all the data files stored in the assignment 1 Vector. The map and bst just index the Vector with no weaterher data in the bst or map.\n\nMy program is mostly working now, but I was thinking of changing to the idea because I think there are many advantages as no data actually moves around or is duplicated. Would you advice changing.',
#   'Answer': "NO. Do not change now. It is the last week of semester. Change means substantial testing again.\n\nComplete the assignment using the approach you have been following. Test rigorously to a careful test plan. Once the assignment is ready for submission, and if you still have time, create a branch of the version from Lab 8. Improve the design of assignment 1 to make it more modular and then work out how to use the alternative approach we discussed in class where the map and BST are used to index the Vector by Date and time. \n\nTo get some inspiration, look at Topic 9/Lec-30.ppt. These are multiway trees, however see how the B+ Tree is different to a B Tree. The list referred in the slide is the Vector we discussed. Also pros/cons of the approach. But don't go building a B+ tree now. \n\nBest not to jump into what we discussed without doing a bit more homework first."},
#  {'Question': 'This week is the last week. What if we fail to show the demonstration for the assignment 2, as we fail to catch up with evrything, due to unfortunate circumstances. \nWe will be getting straight zero for assignment 2 then ?\nIf that is the case, then it would be so much difficult to pass the unit.\nLooking for your kind consideration.',
#   'Answer': "The demonstration in the last week is not of a fully working assignment, so no expectation that you have caught up with everything. \n\nThe parts that are not working are stubbed as indicated in the lab sheet and explained in the workshop. So in the last week you show progress on the assignment and answer your tutor's questions.\n\nThe assignment requires the use of the BST with function pointers from lab 10. Lets say, you have not been able to incorporate Lab 10's BST into the assignment. Let your tutor know. You tutor will ask you to explain how the BST with function pointers work and how you are planning to use it in the assignment. You will need some idea of how it could be used and how the function pointers are used as call backs.\n\nShow your test plan to your tutor and compare the output of the parts that are working with what is in the test plan. Lets say the answers being output are actually *wrong*. That is ok too as long as you can show that the test is failing. It shows the tutor that you are aware that the output is wrong because you have a test plan to check the output and that you are following a development process. These are good practices.\n\nLets assume that you did try the demonstration and still got a zero. Then, because you tried, we can also try to help you. What that means is that if you pass the exam, and particularly if you do well in the exam, your assignment submission can be looked at again. You may have to come in to explain your assignment after the exam.\n\nIt is only when you don't bother or give up, then nothing can be done to help you."},
#  {'Question': 'I have had my BST assessed by my tutor and it meets the requirement of the traversal methods using function pointers. My main concern is I will be using the maps mainly to store the data but use the BST primarily to search and verify that such entries are made in the maps before doing the calculations and I will not be utilising the traversal functions. Will I get zero marks on technicalities if I have relegated my tree to use primarily to search?',
#   'Answer': "No it can't be zero as you are using both map and BST for processing.\n\nSearch is the primary function of the search tree. As you would be using the BST in your processing, you are meeting the assignment's data structure requirements for BST usage. \n\nWhat you get would depend on how well you make your case, and develop (design and implement) your solution."},
#  {'Question': 'My next question is with regards to the use of the keyword auto. As far as I am aware it is of C++11. If I am using it with iterators such as auto itr = map.begin() or auto = myMap.CreateIterator(), Is that approach forbidden?',
#   'Answer': "I had indicated not using auto during class in response to a similar questions some time ago. Thanks for asking to confirm.\n\nIn this unit, everyone has to learn carefully about managing and using type information. The approach you are showing is a nice one, but it doesn't lend itself to learning about types and careful usage of types. The use of auto offloads the type deduction to the compiler. While learning, this task is not to be offloaded.\n\nSo do not use auto in assignment 2. You will be using auto after this unit as you would have learnt careful management and usage of types.\n\nAlso a reminder not to use range for loops.\n\nThe marker can give a mark of 0 if you violate.\n\nThe use of auto and range-for loops are encouraged *after* this unit. But be aware their usage has their own rules that you have to learn."},
#  {'Question': 'My last question is related to wrapping the map in a wrapper class, does operator overloads for operator [], operator = , the copy constructor, and regular constructor count towards the 4-5 public functions allowed for the map to be considered for the bonus?',
#   'Answer': 'It depends on how the private data member of type std::map is declared. Your list may not be minimal. Review how the Stack and Queue classes that were provided in the earlier topics wrapped their corresponding STL versions.'},
# ...
#   'Answer': 'The approach that makes the internal member private is the better approach. There is no need to be explicit in the method name to indicate that the setting is for B. B makes sense to A itself but B does not have to make sense for users of A. B is encapsulated, so sometime down the track, A can swap B out for something else without causing a problem for users of A. You don\'t want users of A to create dependencies with B, the private data of A.\n\nYour Lab 4\'s approach is the better approach. You will get penalised for the first approach if A is a class. A class is used if you want to have controlled access.\n\nAlso consider a more modular approach. Users of A may need to know about B as users of A may have the data that is stored in B. Consider the following:\n\nclass Person{\n\n\tpublic:\n\t\tsetAge(...)\n\t\t\t// what would you pass in as the parameter?\n\t\t\t// is it an integer parameter representing age\n\t\t\t// or a single bit for each call to setAge, so call setAge multiple times, and, \n\t\t\t// each time only 1 bit is set?\n\t\t\t// The question is do you set the age using each low level part of age (1 bit at \n\t\t\t// at a time, or just one quantity that represents age.\n\t\t\t\n\t\t\t// Can you apply the same reasoning in the situation where A contains B?\n\t\t\t// A contains a setter of each constituent of B or A has one setter \n\t\t\t//   setB(const B& b)\n\t\n\n\tprivate:\n\t\tint age;\n\t\t// there can be other attributes here, but not relevant to this discussion\n\n};\n\n\nIf you would like to explore further, please see Chapter 1 "The \nObject Oriented Paradigm" of the ebook "Design Patterns Explained" \n(in our library). Link is: http://tinyurl.com/y3fg3r7a. It was part of topic 1 readings. You can access via LMS or My unit readings from the library.\n\nIt will also give you an idea of the approach we are taking.'},
#  {'Question': 'Will marks be subtracted based on which method we use for error \nhandling?',
#   'Answer': "No, not for trying. May not be allocated for not trying. The easiest way when normal error messages are not sufficient is to use assert. A subroutine must have its precondition valid. If the subroutine can't guarantee its own precondition, it wouldn't be able to do its job.\n\nAssert is also covered in the textbook readings from early in the semester. A short explanation is here http://www.cplusplus.com/reference/cassert/assert/. It has an example on how to use assert, but the error could be handled with a simple error message instead of assert which kills the program. In any case, assert is a good debugging tool too. Use liberally when developing.\n\nYou may have come across try/catch in earlier units. The textbook has a whole chapter on it."},
#  {'Question': 'Instead of using assert to check array bounds, can I throw an exception if index is out of bounds?',
#   'Answer': 'Yes if you want to. Textbook has a chapter on it. List of std::exception is\nhere https://en.cppreference.com/w/cpp/error/exception'},
#  {'Question': 'I have got a lot of assignments due and also have to work. If it is not too much to ask, which chapter in the text do I need to read to do the Vector class?',
#   'Answer': 'The chapter on "Overloading and Templates" listed at the top (highlighted) in the lab 5 sheet. A bloated version of what we need is already there. It is called something else, and so all you have to do is recognise it, rename it and remove the bloat and you have got your solution. Removing the bloat makes it smaller and less to type up too.'},
#  {'Question': 'How do i overload the square bracket operator for const and not const.',
#   'Answer': 'The two versions: Test in isolation first to see which is used when. Remove the cout line once you have understood when each is called. Bounds checking is not shown. The textbook answers your question as well.\n\n    T& operator[] (int i)\n    {\n        cout<<"notconst: "; // just to show the difference in the calls.\n        return a[i]; \t\t// just basic return without any checking to \n\t\t\t\t\t\t\t//demonstrate the essence of the difference\n    }\n\n    const T& operator[] (int i)  const\n    {\n        cout<<"const: ";   // I have added this so that you can see which one is\n\t\t\t\t\t\t\t// called to work out how each version runs when\n        return a[i];\n\nprivate:\n    T a[10]; // basic array, but the operators would be the same if dynamic\n\t\t\t // array allocation is used.\n\t\nThink of why the operators return a reference T& and not just T.\nOnce you have understood the use, remove the & and see the result.\nNote: An lvalue is what can be modified or assigned to.\n\nThe operators are overloaded because the first one is not const and the second is const (declared const on the right side)\n\nA const method or const parameter would need to use the const version of []\n\nAs indicted earlier, the textbook chapter on overloading and templates has more details.'},
#  {'Question': "I'm thinking that I'll modify my Vector template class to have an \ninsertion and deletion method instead of pushBack() and popBack().\nIs this the way to go?",
#   'Answer': 'The Vector is just an encapsulated dynamic array providing controlled\naccess. It should behave like an array. \n\nAs long as you can make a good case for your approach. The methods that you provide shouldn\'t have duplicated functionality and the functionality is best provided as methods. External helper routines  add "good to have" functionality, but methods provide absolutely essential functionality. "Absolutely essential" means that without these methods, the object can\'t do its job. Think carefully about what is the difference between "Absolutely essential" and "really nice to have". Designers have to think about this problem a lot.\n\nThere is also a principle called DRY, that you must become intimately familiar with:\n https://www.geeksforgeeks.org/dont-repeat-yourselfdry-in-software-development/\n\nThe I/O operators from lab 4 were made as external helpers to \ndecouple format issues from classes. These operators were\nmoved to main. The data classes are like the "Model" in MVC pattern. Display and formats are the "View". Do not make Model have a dependency on View.\n\nMore related QandA on this topic below.'},
#  {'Question': "(related questions in lower case q, a)\nRegarding ICT283 Lab 5, when I designed my Vector template class I \nincluded a pushBack() and popBack() function.\n\nHowever this required that I resize the array in which my T-types are being stored.\n\nTo achieve this I've declared and initialized the array...\n\n     a)  T * array = (T *) realloc(array, arraySize)\n\n\n(I've got additional realloc() calls in both the pushBack() and popBack() functions to adjust the amount for memory the array is using based on the number of elements in the array.)\n\n\nThe following seems to behave the same as the code in a):\n\n\n    b) T * array = new T[arraySize];",
#   'Answer': 'Use this high level version in b). \na) is the lower level version, used in C programming.\n\nrealloc also hides other operations that you need to be familiar with and be able to do yourself to really understand the processing requirements and tasks that needs to be carried out. So do not use realloc(). It is not permitted in the assignment.'},
#  {'Question': 'This has made me wonder:\n\nIs there anything special about an array, or is it just a \ncontiguous series of data of the same type stored in memory?',
#   'Answer': 'Nothing special, just contiguous memory. At the level of contiguous \nbytes, the type isn\'t even relevant.\n\nIn the example code (b) that you have for creating array:\n\nOnce you have created the array, of let say, T binds to integer (i.e. int), making array an integer array of arraysize,  and assuming 32 bit ints, I can do this,\n\nchar *dodgyC = (char *) array;\n\ndodgyC[0] is the first byte of the first 4 byte int value of the array you created.\n\nThe pointer type is the "lens" or "window" through which the contiguous series of bytes are viewed when the pointer is dereferenced. [] does pointer arithmetic and then a deference. So array[2] is actually *(array+2). array+2 is the pointer arithmetic (addition) and it is adds 2*sizeof(pointer type) to array.\n\nAssuming a double is 8 bytes (64 bits) on your particular implementation,\n\ndouble *dodgyD = (double *) array;\n\ndodgyD[0] consists of 2 int values (2 x 32 bit ints) from the array but accessed as one element via dodgyD and represented as a 64 bit float - yes dodgy indeed. The two int values are accessed as one element via dodgyD[0] because dodgyD is a double pointer.\n\nWhen accessing memory via a pointer, there is no way to see memory as anything else than the type of the pointer. If you are using an int pointer, you can only see int. If you use a char pointer, you will see char, ... and so on.\n\nSee description of the various builtin types in the textbook or \nhttps://en.cppreference.com/w/cpp/language/types\n\nPointers are powerful, useful but *very dangerous* mechanism. Memory access can happen in unintended ways. You will be experiencing it first-hand, instead of just reading about it, as we are using a powerful programming language. \n\nYou may have heard of what happened in what is called the "largest IT outage in history" when a security company called CrowStrike pushed an improperly checked update.\n\nA memory access violation at the privileged level can have very bad consequences.\n \nCrowdStrike own analysis indicates that the Sensor is written in C++. There was a pointer to an array of 20 elements. It was such a basic error that people learning to program make, trying to access the 21st element - an out of bounds access.  https://www.crowdstrike.com/wp-content/uploads/2024/08/Channel-File-291-Incident-Root-Cause-Analysis-08.06.2024.pdf \n\nYou will be making similar errors in this and later labs and learning from them. For you it is just loss of marks as your code would not be running at a privileged level and the OS will just kill your program. But the consequences when this error happens in production code is staggering. The amount of money that will be finally be involved would be eye-watering.\n\nhttps://ia.acs.org.au/article/2024/crowdstrike-sued-by-shareholders-over-mass-outage.html\n\nThe OS allowed the memory access in privileged mode and damaged itself. There is another lesson to be learnt. Zero trust principle is used in security, but it should also be used in software architecture. \n\nThe other concern that there is with pointers is that when a data structure like the Vector you are building contains pointer to data. Then the rule of 3 applies. See Topic 5, Lec-13.ppt. The required methods must be tested to make sure that the data structure is useable.'},
#  {'Question': "Is it ok, that I've got pushBack() and popBack() methods in my Vector template?",
#   'Answer': 'What would happen if you needed to put a value in a specified location - like the way an array is supposed to behave? i.e random access as opposed to sequential access.\n\nYou would need to provide a method or operator for this access. You would already have a method to return size. Once you provide this random access method, you have duplication of functionality and this is not good from a design point of view. It is not minimal any more. \n\nThere is a (very good) case for pushback as access using operator[] doesn\'t increase size and the [] access enforces bounds strictly. Pushback is needed to keep putting new data into your Vector. In this situation operator [] is used to set/get existing array elements and so there is no duplication by pushback. See Rule 80 in coding standards.\n\n{There was a some debate in class about naming. The term "Push" is used for a very different data structure called Stack. A Vector is not a Stack, so pushback could be avoided. Preferred term is insert or maybe insert-end. I am indicating "maybe" as the term "end" is dictating implementation approach in the specs. The specs should avoid implementation concerns as the specs should aim for abstraction where possible. For data structures that can grow, and the Vector that you are building is such a data structure, the Coding Standards advice using pushback. See discussion for rule 80 in the coding standards.\n\nShould also consider if increasing size in [] is expected behaviour. Semantics of overloaded operators should not change. This rule applies to all overloaded operators. The usual [] operator doesn\'t increase size and by increasing size, in [] the semantics of [] is changed. Can you think of the pros/cons of allowing size change in []? Think of consequences good/bad of allowing size change in [].}'},
#  {'Question': 'Can I use our Vector later or remove it completely and use the map and other data structures needed for assignment 2.',
#   'Answer': 'The choice is entirely up to you. You decide on how you would use the various data structures, what combinations to use as long as the map and the required tree data structure (covered later) is used. \n\n**We are rapidly moving to situations where you make the decisions and you must defend your design decisions.** Industry expects our grads to be able to do this.\n\nAll choices needs to be defended (rationale provided with discussion of pros/cons).\n\nFor the lab 8 exercises, follow the instructions in Lab 8.'},
#  {'Question': 'Do I need to write test plans as in the 3rd year units samples.',
#   'Answer': 'No, keep it simple. See the PowerPoint notes example for Calculator. Our assignments are smaller than 3rd year projects. What you need to take into third year is that there are different types of testing beyond unit and application tests done in ict283.'},
#  {'Question': "In some of the datafiles, some fields are recorded as 'N/A'. Is in an error in the datafile or we should write a code to handle these situations?",
#   'Answer': 'Yes, your code filters out (ignores the NA). It normally means that sensors were offline and so the data logger software recorded that.\n\nIt depends a lot on who wrote the data logger software. So it is not an error. A different programmer would take a different approach in writing the data logger using empty field. An empty field is denoted by two commas in sequence:\n\ndata,some data,,data,data\n\nThe two commas in sequence ,, means that there was no value in between them. It is like the NA.\n\nYour can decide to ignore the whole line if\n1. there is an NA (or empty) in any field, or\n2. there is an NA (or empty) in any of the required fields that was being used for assignment 1 (and later in Assignment 2)\n\nYou choose either 1 or 2 from above but you must explain your reasoning.'},
#  {'Question': 'Can I test with all the files provided? Can I use more?',
#   'Answer': "Yes and you can use more. If you download your own files.\n\nTo test your data structure and your program, you could just duplicate the same file listings repeatedly in the data/data_source.txt file. For example to test how fast your program can read the data files, list 20 or more files in the data_source.txt file. It doesn't matter if the files are repeated in the index file as you are just checking if you can read and load so much data stress testing your data structure and checking for inefficiencies in your code. Remember the light construction code from the earlier topic\n\nBut, for real testing to the test plan, create smaller specially designed test files that test specific conditions specified in your test plan. What is in a properly designed test plan is the real test that we are after. See lecture notes for this topic 8. Look at the test files provided for the third year units to get an even better understanding of where we are going."}]

# %%
import json

def create_json(pair_list):
    
    with open('data.json', 'w') as file:
        json.dump(pair_list, file, indent=4)
        
create_json(pairs)
